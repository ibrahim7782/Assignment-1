# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile"

# %%
response= requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>APSRTC Online Bus Ticket Booking, Bus Reservation, Time Table, Fares - redBus</title>
# <link href="https://www.redbus.in/online-booking/apsrtc" rel="canonical"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="initial-scale=1.0" name="viewport"/>
# <meta content="Book APSRTC bus tickets online at redBus. Check APSRTC online bus fares, bus timetable, use code FIRST to get 10% discount up to Rs 150 + Rs 100 cashback on APSRTC bus ticket booking." name="description"/>
# <meta content="Travel" name="classification"/>
# <meta content="index, follow" name="robots"/>
# <link href="/seoassets/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <link as="font" crossorigin="" href="/seoassets/fonts/Montserrat-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/seoassets/fonts/Montserrat-SemiBold.woff2" rel="preload" type="font/woff2"/>
# ...

# %%
RouteName = soup.select(".route")

# %%
RouteName
# Out:
# [<a class="route" href="/bus-tickets/vijayawada-to-hyderabad" title="Vijayawada to Hyderabad">Vijayawada to Hyderabad</a>,
#  <a class="route" href="/bus-tickets/hyderabad-to-vijayawada" title="Hyderabad to Vijayawada">Hyderabad to Vijayawada</a>,
#  <a class="route" href="/bus-tickets/kakinada-to-visakhapatnam" title="Kakinada to Visakhapatnam">Kakinada to Visakhapatnam</a>,
#  <a class="route" href="/bus-tickets/bangalore-to-tirupathi" title="Bangalore to Tirupati">Bangalore to Tirupati</a>,
#  <a class="route" href="/bus-tickets/visakhapatnam-to-kakinada" title="Visakhapatnam to Kakinada">Visakhapatnam to Kakinada</a>,
#  <a class="route" href="/bus-tickets/kadapa-to-bangalore" title="Kadapa to Bangalore">Kadapa to Bangalore</a>,
#  <a class="route" href="/bus-tickets/bangalore-to-kadapa" title="Bangalore to Kadapa">Bangalore to Kadapa</a>,
# ...

# %%
FirstBus = soup.select(".totalRoutes:nth-child(2)")

# %%
FirstBus
# Out:
# [<span class="totalRoutes">First Bus<!-- --> : <strong>00:05</strong></span>,
#  <span class="totalRoutes">First Bus<!-- --> : <strong>00:10</strong></span>,
#  <span class="totalRoutes">First Bus<!-- --> : <strong>00:30</strong></span>,
#  <span class="totalRoutes">First Bus<!-- --> : <strong>03:30</strong></span>,
#  <span class="totalRoutes">First Bus<!-- --> : <strong>00:25</strong></span>,
#  <span class="totalRoutes">First Bus<!-- --> : <strong>00:25</strong></span>,
#  <span class="totalRoutes">First Bus<!-- --> : <strong>04:00</strong></span>,
#  <span class="totalRoutes">First Bus<!-- --> : <strong>01:30</strong></span>,
#  <span class="totalRoutes">First Bus<!-- --> : <strong>00:30</strong></span>,
#  <span class="totalRoutes">First Bus<!-- --> : <strong>00:30</strong></span>]

# %%
LastBus= soup.select(".totalRoutes~ .totalRoutes+ .totalRoutes")

# %%
LastBus
# Out:
# [<span class="totalRoutes">Last Bus<!-- --> : <strong>23:55</strong></span>,
#  <span class="totalRoutes">Last Bus<!-- --> : <strong>23:55</strong></span>,
#  <span class="totalRoutes">Last Bus<!-- --> : <strong>23:40</strong></span>,
#  <span class="totalRoutes">Last Bus<!-- --> : <strong>23:55</strong></span>,
#  <span class="totalRoutes">Last Bus<!-- --> : <strong>23:55</strong></span>,
#  <span class="totalRoutes">Last Bus<!-- --> : <strong>23:50</strong></span>,
#  <span class="totalRoutes">Last Bus<!-- --> : <strong>23:50</strong></span>,
#  <span class="totalRoutes">Last Bus<!-- --> : <strong>23:59</strong></span>,
#  <span class="totalRoutes">Last Bus<!-- --> : <strong>23:59</strong></span>,
#  <span class="totalRoutes">Last Bus<!-- --> : <strong>23:55</strong></span>]

# %%
Price= soup.select(".fare")

# %%
Price
# Out:
# [<span class="fare"> <!-- -->INR 436</span>,
#  <span class="fare"> <!-- -->INR 367</span>,
#  <span class="fare"> <!-- -->INR 239</span>,
#  <span class="fare"> <!-- -->INR 280</span>,
#  <span class="fare"> <!-- -->INR 239</span>,
#  <span class="fare"> <!-- -->INR 412</span>,
#  <span class="fare"> <!-- -->INR 388</span>,
#  <span class="fare"> <!-- -->INR 186</span>,
#  <span class="fare"> <!-- -->INR 250</span>,
#  <span class="fare"> <!-- -->INR 264</span>]

# %%
import pandas

# %%
BusTiming = pandas.DataFrame(RouteName,columns=['Route Name'])

# %%
BusTiming
# Out:
#                                 Route Name
# 0                  Vijayawada to Hyderabad
# 1                  Hyderabad to Vijayawada
# 2                Kakinada to Visakhapatnam
# 3                    Bangalore to Tirupati
# 4                Visakhapatnam to Kakinada
# 5                      Kadapa to Bangalore
# 6                      Bangalore to Kadapa
# 7   Chittoor (Andhra Pradesh) to Bangalore
# 8  Anantapur (andhra pradesh) to Bangalore
# 9                    Tirupati to Bangalore

# %%
BusTiming["First bus Time"] = FirstBus

# %%
BusTiming["Last Bus Time"] = LastBus

# %%
BusTiming["Ticket Price"] = Price

# %%
BusTiming
# Out:
#                                 Route Name                First bus Time  \
# 0                  Vijayawada to Hyderabad  [First Bus,  ,  : , [00:05]]
# 1                  Hyderabad to Vijayawada  [First Bus,  ,  : , [00:10]]
# 2                Kakinada to Visakhapatnam  [First Bus,  ,  : , [00:30]]
# 3                    Bangalore to Tirupati  [First Bus,  ,  : , [03:30]]
# 4                Visakhapatnam to Kakinada  [First Bus,  ,  : , [00:25]]
# 5                      Kadapa to Bangalore  [First Bus,  ,  : , [00:25]]
# 6                      Bangalore to Kadapa  [First Bus,  ,  : , [04:00]]
# 7   Chittoor (Andhra Pradesh) to Bangalore  [First Bus,  ,  : , [01:30]]
# 8  Anantapur (andhra pradesh) to Bangalore  [First Bus,  ,  : , [00:30]]
# 9                    Tirupati to Bangalore  [First Bus,  ,  : , [00:30]]
#
#                  Last Bus Time     Ticket Price
# 0  [Last Bus,  ,  : , [23:55]]  [ ,  , INR 436]
# 1  [Last Bus,  ,  : , [23:55]]  [ ,  , INR 367]
# ...

# %%
BusTiming.to_csv("C:\\Users\\aedpu\\OneDrive\\Documents\\assignment.csv")
